# %%
import gensim
from gensim.models import CoherenceModel
from gensim.corpora import Dictionary, MmCorpus
import matplotlib.pyplot as plt
import os
import time
import json
# %env JOBLIB_TEMP_FOLDER= 'E:/sp2023stock/TopicModeling/tmp'
# Out:
# env: JOBLIB_TEMP_FOLDER='E:/sp2023stock/TopicModeling/tmp'

# %%
#input
main = os.getcwd()
model_path_asset = main + "/../model/ModelingAssets/CorpusDict"
model_save_path = main + "/../model/Modeling_n_Topics"

plot_save_path = main + "/../result/Evaluation//Model_Comparison_v2.2.png"


num = 25
model_path_asset_spenum = model_path_asset+str(num)
print(main)
# Out:
# E:\sp2023stock\TopicModeling\src

# %%
# Path to save the plot
print("Setting path plotting - model")

print("Dataset loading  dictionary - corpus - json")
# Load the dictionary and corpus
dictionary = Dictionary.load(f'{model_path_asset_spenum}/dictionary.gensim')
corpus = MmCorpus(f'{model_path_asset_spenum}/corpus.mm')
json_file_path = f'{model_path_asset_spenum}/dataset_{num}.json'

with open(json_file_path, 'r', encoding='utf-8') as json_file:
    dataset = json.load(json_file)
    
print(f"Dataset loaded - dictionary {len(dictionary)} - corpus {len(corpus)} - json")
# Out:
# Setting path plotting - model
# Dataset loading  dictionary - corpus - json
# Dataset loaded - dictionary 81821 - corpus 126502 - json

# %%
# %env JOBLIB_TEMP_FOLDER= 'E:/sp2023stock/TopicModeling/tmp'

num_topics_list = range(100, 800, 100)

coherences_cv = []
coherences_umass = []
total_time = []

for topics in num_topics_list:
    print(f'Starting evaluation for {topics} topics')
    start_time = time.time()

    # Initialize and train the LDA model
    lda = gensim.models.ldamulticore.LdaMulticore(
        corpus=corpus, 
        id2word=dictionary, 
        num_topics=topics, 
        iterations= 1000, 
        workers =os.cpu_count() - 1 )
  
    model_filename = os.path.join(model_save_path, f'lda_model_n{topics}_passes{total_passes}_size{num}.gensim')
    lda.save(model_filename)
    print(f'Model with {topics} topics saved to {model_filename}')

    # Calculate coherence c_v
    coherence_model_lda_cv = CoherenceModel(model=lda, texts=dataset, dictionary=dictionary, coherence='c_v')
    coherence_lda_cv = coherence_model_lda_cv.get_coherence()
    coherences_cv.append(coherence_lda_cv)

    # Calculate coherence U_mass
    coherence_model_lda_umass = CoherenceModel(model=lda, corpus=corpus, dictionary=dictionary, coherence='u_mass')
    coherence_lda_umass = coherence_model_lda_umass.get_coherence()
    coherences_umass.append(coherence_lda_umass)

    print(f"Topics: {topics}, Coherence c_v: {coherence_lda_cv}, Coherence u_mass: {coherence_lda_umass}")

    end_time = time.time()
    time_taken = end_time - start_time
    total_time.append(time_taken)
    print(f"Number of Topics: {topics}, Time taken: {time_taken} seconds")

# Plotting the Coherence Scores
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(num_topics_list, coherences_cv, marker='o', color='b', label='c_v')
plt.title('C_V Coherence Scores for Different Number of Topics')
plt.xlabel('Number of Topics')
plt.ylabel('Coherence Score (c_v)')

plt.subplot(1, 2, 2)
plt.plot(num_topics_list, coherences_umass, marker='o', color='r', label='u_mass')
plt.title('U_Mass Coherence Scores for Different Number of Topics')
plt.xlabel('Number of Topics')
plt.ylabel('Coherence Score (u_mass)')
plt.legend()

plt.tight_layout()
plt.savefig(plot_save_path)
plt.show()

print("Evaluation complete.")
# Out:
# env: JOBLIB_TEMP_FOLDER='E:/sp2023stock/TopicModeling/tmp'
# Starting evaluation for 100 topics
# Model with 100 topics saved to E:\sp2023stock\TopicModeling\src/../model/Modeling_n_Topics\lda_model_n100_passes1000_size25.gensim
# Topics: 100, Coherence c_v: 0.5448227003423093, Coherence u_mass: -3.502769035627531
# Number of Topics: 100, Time taken: 17698.27016210556 seconds
# Starting evaluation for 200 topics
# Model with 200 topics saved to E:\sp2023stock\TopicModeling\src/../model/Modeling_n_Topics\lda_model_n200_passes1000_size25.gensim
# Topics: 200, Coherence c_v: 0.5050028598553411, Coherence u_mass: -5.386217540716769
# Number of Topics: 200, Time taken: 27448.04470229149 seconds
# Starting evaluation for 300 topics
# Model with 300 topics saved to E:\sp2023stock\TopicModeling\src/../model/Modeling_n_Topics\lda_model_n300_passes1000_size25.gensim
# Topics: 300, Coherence c_v: 0.5000981760213536, Coherence u_mass: -6.6125643570636585
# Number of Topics: 300, Time taken: 39098.195788145065 seconds
# Starting evaluation for 400 topics
# Model with 400 topics saved to E:\sp2023stock\TopicModeling\src/../model/Modeling_n_Topics\lda_model_n400_passes1000_size25.gensim
# Topics: 400, Coherence c_v: 0.4822387471144124, Coherence u_mass: -7.710426349020513
# Number of Topics: 400, Time taken: 51470.11572813988 seconds
# Starting evaluation for 500 topics
# Model with 500 topics saved to E:\sp2023stock\TopicModeling\src/../model/Modeling_n_Topics\lda_model_n500_passes1000_size25.gensim
# Topics: 500, Coherence c_v: 0.46627620907378525, Coherence u_mass: -8.619089693513931
# Number of Topics: 500, Time taken: 64555.84953045845 seconds
# Starting evaluation for 600 topics
# Model with 600 topics saved to E:\sp2023stock\TopicModeling\src/../model/Modeling_n_Topics\lda_model_n600_passes1000_size25.gensim
# Topics: 600, Coherence c_v: 0.455448320016234, Coherence u_mass: -9.107025951725857
# Number of Topics: 600, Time taken: 78171.11727571487 seconds
# Starting evaluation for 700 topics
# Model with 700 topics saved to E:\sp2023stock\TopicModeling\src/../model/Modeling_n_Topics\lda_model_n700_passes1000_size25.gensim
# Topics: 700, Coherence c_v: 0.4464101891349979, Coherence u_mass: -9.608476285587624
# Number of Topics: 700, Time taken: 91501.2948858738 seconds
# Evaluation complete.

# %%
# %env JOBLIB_TEMP_FOLDER= 'E:/sp2023stock/TopicModeling/tmp'

num_topics_list = range(100, 1000, 100)
total_iterations = 1000
coherences_cv = []
coherences_umass = []
total_time = []

for topics in num_topics_list:
    print(f'Starting evaluation for {topics} topics')
    start_time = time.time()

    # Initialize and train the LDA model
    lda = gensim.models.ldamulticore.LdaMulticore(
        corpus=corpus, 
        id2word=dictionary, 
        num_topics=topics, 
        iterations= total_iterations, 
        workers =os.cpu_count() - 1 )
  
    model_filename = os.path.join(model_save_path, f'lda_model_n{topics}_iteration{total_iterations}_size{num}.gensim')
    lda.save(model_filename)
    print(f'Model with {topics} topics saved to {model_filename}')

    # Calculate coherence c_v
    coherence_model_lda_cv = CoherenceModel(model=lda, texts=dataset, dictionary=dictionary, coherence='c_v')
    coherence_lda_cv = coherence_model_lda_cv.get_coherence()
    coherences_cv.append(coherence_lda_cv)

    # Calculate coherence U_mass
    coherence_model_lda_umass = CoherenceModel(model=lda, corpus=corpus, dictionary=dictionary, coherence='u_mass')
    coherence_lda_umass = coherence_model_lda_umass.get_coherence()
    coherences_umass.append(coherence_lda_umass)

    print(f"Topics: {topics}, Coherence c_v: {coherence_lda_cv}, Coherence u_mass: {coherence_lda_umass}")

    end_time = time.time()
    time_taken = end_time - start_time
    total_time.append(time_taken)
    print(f"Number of Topics: {topics}, Time taken: {time_taken} seconds")

# Plotting the Coherence Scores
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(num_topics_list, coherences_cv, marker='o', color='b', label='c_v')
plt.title('C_V Coherence Scores for Different Number of Topics')
plt.xlabel('Number of Topics')
plt.ylabel('Coherence Score (c_v)')

plt.subplot(1, 2, 2)
plt.plot(num_topics_list, coherences_umass, marker='o', color='r', label='u_mass')
plt.title('U_Mass Coherence Scores for Different Number of Topics')
plt.xlabel('Number of Topics')
plt.ylabel('Coherence Score (u_mass)')
plt.legend()

plt.tight_layout()
plt.savefig(plot_save_path)
plt.show()

print("Evaluation complete.")
# Out:
# env: JOBLIB_TEMP_FOLDER='E:/sp2023stock/TopicModeling/tmp'
# Starting evaluation for 100 topics
# Model with 100 topics saved to E:\sp2023stock\TopicModeling\src/../model/Modeling_n_Topics\lda_model_n100_iteration1000_size25.gensim
# Topics: 100, Coherence c_v: 0.36152565096960687, Coherence u_mass: -1.8540055779926725
# Number of Topics: 100, Time taken: 106.73065829277039 seconds
# Starting evaluation for 200 topics
# Model with 200 topics saved to E:\sp2023stock\TopicModeling\src/../model/Modeling_n_Topics\lda_model_n200_iteration1000_size25.gensim
# Topics: 200, Coherence c_v: 0.36272728362397216, Coherence u_mass: -1.839025571027185
# Number of Topics: 200, Time taken: 140.80712795257568 seconds
# Starting evaluation for 300 topics
# Model with 300 topics saved to E:\sp2023stock\TopicModeling\src/../model/Modeling_n_Topics\lda_model_n300_iteration1000_size25.gensim
# Topics: 300, Coherence c_v: 0.36422412982594493, Coherence u_mass: -2.0675737200566937
# Number of Topics: 300, Time taken: 185.39167380332947 seconds
# Starting evaluation for 400 topics
# Model with 400 topics saved to E:\sp2023stock\TopicModeling\src/../model/Modeling_n_Topics\lda_model_n400_iteration1000_size25.gensim
# Topics: 400, Coherence c_v: 0.3581557872959571, Coherence u_mass: -2.419435252590396
# Number of Topics: 400, Time taken: 237.6321976184845 seconds
# Starting evaluation for 500 topics
# Model with 500 topics saved to E:\sp2023stock\TopicModeling\src/../model/Modeling_n_Topics\lda_model_n500_iteration1000_size25.gensim
# Topics: 500, Coherence c_v: 0.368133889506355, Coherence u_mass: -2.871459295996611
# Number of Topics: 500, Time taken: 344.4640967845917 seconds
# Starting evaluation for 600 topics
# Model with 600 topics saved to E:\sp2023stock\TopicModeling\src/../model/Modeling_n_Topics\lda_model_n600_iteration1000_size25.gensim
# Topics: 600, Coherence c_v: 0.36355947550463447, Coherence u_mass: -3.0358326469575356
# Number of Topics: 600, Time taken: 466.2468192577362 seconds
# Starting evaluation for 700 topics
# Model with 700 topics saved to E:\sp2023stock\TopicModeling\src/../model/Modeling_n_Topics\lda_model_n700_iteration1000_size25.gensim
# Topics: 700, Coherence c_v: 0.3690282925930077, Coherence u_mass: -3.006787257665103
# Number of Topics: 700, Time taken: 593.4479577541351 seconds
# Starting evaluation for 800 topics
# Model with 800 topics saved to E:\sp2023stock\TopicModeling\src/../model/Modeling_n_Topics\lda_model_n800_iteration1000_size25.gensim
# Topics: 800, Coherence c_v: 0.38013176593171877, Coherence u_mass: -3.023408589967039
# Number of Topics: 800, Time taken: 763.9083096981049 seconds
# Starting evaluation for 900 topics
# Model with 900 topics saved to E:\sp2023stock\TopicModeling\src/../model/Modeling_n_Topics\lda_model_n900_iteration1000_size25.gensim
# Topics: 900, Coherence c_v: 0.38937228058512247, Coherence u_mass: -2.9991355428240767
# Number of Topics: 900, Time taken: 764.5119307041168 seconds
# Evaluation complete.

# %%
# %env JOBLIB_TEMP_FOLDER= 'E:/sp2023stock/TopicModeling/tmp'

num_topics_list = range(100, 1300, 200)
total_iterations = 1000
coherences_cv = []
coherences_umass = []
total_time = []

for topics in num_topics_list:
    print(f'Starting evaluation for {topics} topics')
    start_time = time.time()

    # Initialize and train the LDA model
    lda = gensim.models.ldamulticore.LdaMulticore(
        corpus=corpus, 
        id2word=dictionary, 
        num_topics=topics, 
        iterations= total_iterations, 
        workers =os.cpu_count() - 1 )
  
    model_filename = os.path.join(model_save_path, f'lda_model_n{topics}_iteration{total_iterations}_size{num}.gensim')
    lda.save(model_filename)
    print(f'Model with {topics} topics saved to {model_filename}')

    # Calculate coherence c_v
    coherence_model_lda_cv = CoherenceModel(model=lda, texts=dataset, dictionary=dictionary, coherence='c_v')
    coherence_lda_cv = coherence_model_lda_cv.get_coherence()
    coherences_cv.append(coherence_lda_cv)

    # Calculate coherence U_mass
    coherence_model_lda_umass = CoherenceModel(model=lda, corpus=corpus, dictionary=dictionary, coherence='u_mass')
    coherence_lda_umass = coherence_model_lda_umass.get_coherence()
    coherences_umass.append(coherence_lda_umass)

    print(f"Topics: {topics}, Coherence c_v: {coherence_lda_cv}, Coherence u_mass: {coherence_lda_umass}")

    time_taken = end_time - start_time
    total_time.append(time_taken)
    # Process completed successfully
    end_time = cmd.time.time()
    
    def format_duration(seconds):
        """Convert seconds to hours, minutes, and seconds."""
        hours = seconds // 3600
        minutes = (seconds % 3600) // 60
        seconds = seconds % 60
        return f"{int(hours)}h {int(minutes)}m {int(seconds)}s"
        
    print("----------------------------------------------")
    print(f"Number of Topics: {topics,} Process completed. Total runtime: ", format_duration(end_time - start_time))
    print("----------------------------------------------")
    print("\n")
    print("\n")


# Plotting the Coherence Scores
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(num_topics_list, coherences_cv, marker='o', color='b', label='c_v')
plt.title('C_V Coherence Scores for Different Number of Topics')
plt.xlabel('Number of Topics')
plt.ylabel('Coherence Score (c_v)')

plt.subplot(1, 2, 2)
plt.plot(num_topics_list, coherences_umass, marker='o', color='r', label='u_mass')
plt.title('U_Mass Coherence Scores for Different Number of Topics')
plt.xlabel('Number of Topics')
plt.ylabel('Coherence Score (u_mass)')
plt.legend()

plt.tight_layout()
plt.savefig(plot_save_path)
plt.show()

print("Evaluation complete.")
# Out:
# env: JOBLIB_TEMP_FOLDER='E:/sp2023stock/TopicModeling/tmp'
# Starting evaluation for 100 topics
# Model with 100 topics saved to E:\sp2023stock\TopicModeling\src/../model/Modeling_n_Topics\lda_model_n100_iteration1000_size25.gensim
# Topics: 100, Coherence c_v: 0.3745453175176101, Coherence u_mass: -1.8287725618933286
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 37
#      33 coherences_umass.append(coherence_lda_umass)
#      35 print(f"Topics: {topics}, Coherence c_v: {coherence_lda_cv}, Coherence u_mass: {coherence_lda_umass}")
# ---> 37 time_taken = end_time - start_time
#      38 total_time.append(time_taken)
#      39 # Process completed successfully
#
# NameError: name 'end_time' is not defined
