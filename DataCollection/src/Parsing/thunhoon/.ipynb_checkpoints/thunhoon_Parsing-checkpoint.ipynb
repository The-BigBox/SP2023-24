# %%
import os
import csv
import re
import pandas as pd
import chardet
import datetime
from bs4 import BeautifulSoup


# *start using "parsing_progress.txt" (current progress of parsing)
if os.path.exists('parsing_progress.txt'):
    with open('parsing_progress.txt','r') as f:
        progress_start = int(f.readline().strip())
        start_id = progress_start - 1
else: 
    start_id = 1 
    
article_id = start_id


process = 'E:/Crimson_News/src/CrawlingCode/thunhoon/progress.txt'


# *end using "progress" (last progress of crwaling)
if os.path.exists(process):
    with open(process,'r') as f:
        progress_end = int(f.readline().strip())
        end_id = progress_end + 1

# %%
print(start_id,end_id)

# %%
# Detect input file
def htmlInput(file_path):
    with open(file_path, "rb") as file:
        encoding_result = chardet.detect(file.read())
    with open(file_path, "r", encoding=encoding_result["encoding"]) as file:
        html_content = file.read()
    soup = BeautifulSoup(html_content, "html.parser")
    return soup

#Extract title
def extract_title(soup):
    title = soup.title.string.strip() if soup.title else None
    return title

#Extract body
def extract_body(soup):
    article_divs = soup.find_all("div", class_="article-p")
    articles = []
    if article_divs:
        for article_div in article_divs:
            for p in article_div.find_all('p', {'style': 'text-align:right'}):  # if <div> contains <p style="text-align:right">
                p.decompose()  # remove <p> tag
            articles.append(article_div.get_text(strip=True))
    
        articles = [s.replace('\n', ' ') for s in articles]
        articles = [s.replace('\xa0', ' ') for s in articles]
        articles = [item for item in articles if item != '']

    
    return articles


#Extract tags
def extract_tags(soup):
    tagcloud_span = soup.find("h6", class_="newsTagColor")
    
    if tagcloud_span is not None:
        tags = tagcloud_span.find_all('a')
        tag_content = [tag.get_text(strip=True) for tag in tags]
        tag_content = [item for item in tag_content if item != '']
    else:
        tag_content = None
    
    return tag_content

def extract_pubdate(soup):
    month_list = {
        'มกราคม': '01', 
        'กุมภาพันธ์': '02', 
        'มีนาคม': '03', 
        'เมษายน': '04', 
        'พฤษภาคม': '05', 
        'มิถุนายน': '06', 
        'กรกฎาคม': '07', 
        'สิงหาคม': '08', 
        'กันยายน': '09', 
        'ตุลาคม': '10', 
        'พฤศจิกายน': '11', 
        'ธันวาคม': '12'
    }
    
    # Assuming soup is already defined with your HTML content
    date_time_div = soup.find("p", class_=re.compile("^Article__PublishTimeStamp-sc-18ssv56-0"))
    
    if date_time_div is not None:
        date_time_string = date_time_div.get_text(strip=True)
    
        # Split the string into words
        words = date_time_string.split()
    
        # Identify the components
        day = words[0]
        month = month_list.get(words[1])  # Get the numeric month
        year = words[2]
        time = words[4]
    
        # Form the date and time in the desired format
        pubdate = f"{year}-{month}-{day} {time}"
    else:
        pubdate = None
    
    return pubdate

#Extract title
def extract_intro(soup):
    intro_div = soup.find("h2", class_="entry-sub-title")
    intro = ""
    if intro_div:
        intro = intro_div.get_text(strip=True)
    else:
        intro = None

    return intro

def extract_urlPic(soup):
    url = None
    return url


for article_id in range(start_id, end_id+1):
    file_path = os.path.join("E:/Crimson_News/DataSet/thunhoon/article/" + str(article_id) +"/index.txt")
    
    if os.path.exists(file_path):
        try:
            soup = htmlInput(file_path)
            title = extract_title(soup)
            intro = extract_intro(soup)
            articles = extract_body(soup)
            pubdate = extract_pubdate(soup)
            tag_content = extract_tags(soup)
            url = extract_urlPic(soup)
            
            data_dict = {'Title': title, 'Intro': intro, 'Article': articles, 'DateTime': pubdate, 'Tags': tag_content, 'url_picture': url}
            
        
            with open(os.path.join("E:/Crimson_News/DataSet/thunhoon/article/" + str(article_id) +"/parsing.txt"), 'w', encoding="utf-8") as f:
                for key, value in data_dict.items():
                    if value is not None:
                        if key == 'Tags' and isinstance(value, list):
                            f.write(f"[::{key}::]\n")
                            for tags in value:
                                f.write(f"{tags}\n")

                        elif key == 'Article' and isinstance(value, list):
                            f.write(f"[::{key}::]\n")
                            for bodys in value:
                                if bodys == 'SPONSORED':
                                    continue
                                else:
                                    f.write(f"{bodys}\n")
                                    f.write("\n")
                        else:
                            f.write(f"[::{key}::]\n{value}\n")


            with open('parsing_progress.txt', 'w') as f:
                f.write(f'{article_id}')

            with open('parsing_number.csv', 'a', newline='') as f:
                writer = csv.writer(f)
                validation = 'Valid'
                writer.writerow([article_id, validation])

                    
        except Exception as e:
            print(f"Error processing article {article_id}: {e}")
            with open('parsing_number.csv', 'a', newline='') as f:
                writer = csv.writer(f)
                validation = 'Error'
                writer.writerow([article_id, validation])
                continue


# Write the last processed article_id to 'csv_progress.txt' after loop ends
with open('parsing_progress.txt', 'w') as f:
    f.write(str(article_id) + '\n')
# Out:
# Error processing article 219816: 'charmap' codec can't decode byte 0x81 in position 548: character maps to <undefined>
# Error processing article 220239: 'charmap' codec can't decode byte 0x81 in position 548: character maps to <undefined>
# Error processing article 221023: 'charmap' codec can't decode byte 0x81 in position 548: character maps to <undefined>
# Error processing article 222189: 'charmap' codec can't decode byte 0x81 in position 548: character maps to <undefined>
# Error processing article 223090: 'charmap' codec can't decode byte 0x81 in position 548: character maps to <undefined>
# Error processing article 224225: 'charmap' codec can't decode byte 0x81 in position 548: character maps to <undefined>
# Error processing article 224673: 'charmap' codec can't decode byte 0x81 in position 548: character maps to <undefined>
# Error processing article 227307: 'charmap' codec can't decode byte 0x81 in position 548: character maps to <undefined>
# Error processing article 227317: 'charmap' codec can't decode byte 0x81 in position 548: character maps to <undefined>
# Error processing article 227459: 'charmap' codec can't decode byte 0x81 in position 548: character maps to <undefined>
# Error processing article 234508: 'charmap' codec can't decode byte 0x81 in position 548: character maps to <undefined>
# Error processing article 235965: 'charmap' codec can't decode byte 0x81 in position 548: character maps to <undefined>
# Error processing article 242464: 'charmap' codec can't decode byte 0x81 in position 548: character maps to <undefined>
# Error processing article 243402: 'charmap' codec can't decode byte 0x81 in position 548: character maps to <undefined>
# Error processing article 244391: 'charmap' codec can't decode byte 0x81 in position 548: character maps to <undefined>
# Error processing article 244885: 'charmap' codec can't decode byte 0x81 in position 548: character maps to <undefined>
# Error processing article 246385: 'charmap' codec can't decode byte 0x81 in position 548: character maps to <undefined>
# Error processing article 247521: 'charmap' codec can't decode byte 0x81 in position 548: character maps to <undefined>
# Error processing article 249211: 'charmap' codec can't decode byte 0x81 in position 548: character maps to <undefined>
# Error processing article 249724: 'charmap' codec can't decode byte 0x81 in position 548: character maps to <undefined>
# Error processing article 249741: 'charmap' codec can't decode byte 0x81 in position 548: character maps to <undefined>
# Error processing article 250878: 'charmap' codec can't decode byte 0x81 in position 548: character maps to <undefined>
# Error processing article 252971: 'charmap' codec can't decode byte 0x81 in position 548: character maps to <undefined>
# Error processing article 255446: 'charmap' codec can't decode byte 0x81 in position 548: character maps to <undefined>
# Error processing article 256392: 'charmap' codec can't decode byte 0x81 in position 548: character maps to <undefined>
# Error processing article 258044: 'charmap' codec can't decode byte 0x81 in position 548: character maps to <undefined>
# Error processing article 258789: 'charmap' codec can't decode byte 0x81 in position 548: character maps to <undefined>
# Error processing article 259105: 'charmap' codec can't decode byte 0x81 in position 548: character maps to <undefined>
# Error processing article 259162: 'charmap' codec can't decode byte 0x81 in position 548: character maps to <undefined>
# Error processing article 259178: 'charmap' codec can't decode byte 0x81 in position 548: character maps to <undefined>
# Error processing article 259806: 'charmap' codec can't decode byte 0x81 in position 548: character maps to <undefined>
# Error processing article 260953: 'charmap' codec can't decode byte 0x81 in position 548: character maps to <undefined>
# Error processing article 261510: 'charmap' codec can't decode byte 0x81 in position 548: character maps to <undefined>
# Error processing article 261511: 'charmap' codec can't decode byte 0x81 in position 548: character maps to <undefined>
# Error processing article 261513: 'charmap' codec can't decode byte 0x81 in position 548: character maps to <undefined>
# Error processing article 261514: 'charmap' codec can't decode byte 0x81 in position 548: character maps to <undefined>
# Error processing article 261515: 'charmap' codec can't decode byte 0x81 in position 548: character maps to <undefined>
# Error processing article 261516: 'charmap' codec can't decode byte 0x81 in position 548: character maps to <undefined>
# Error processing article 261518: 'charmap' codec can't decode byte 0x81 in position 548: character maps to <undefined>
# Error processing article 261566: 'charmap' codec can't decode byte 0x81 in position 548: character maps to <undefined>
# Error processing article 261776: 'charmap' codec can't decode byte 0x81 in position 548: character maps to <undefined>
# Error processing article 261778: 'charmap' codec can't decode byte 0x81 in position 548: character maps to <undefined>
# Error processing article 261779: 'charmap' codec can't decode byte 0x81 in position 548: character maps to <undefined>
# Error processing article 263710: 'charmap' codec can't decode byte 0x81 in position 548: character maps to <undefined>
# Error processing article 265843: 'charmap' codec can't decode byte 0x81 in position 548: character maps to <undefined>
# Error processing article 268656: 'charmap' codec can't decode byte 0x81 in position 548: character maps to <undefined>
# Error processing article 269023: 'charmap' codec can't decode byte 0x81 in position 548: character maps to <undefined>
# Error processing article 269073: 'charmap' codec can't decode byte 0x81 in position 548: character maps to <undefined>
# Error processing article 269238: 'charmap' codec can't decode byte 0x81 in position 548: character maps to <undefined>
# Error processing article 269244: 'charmap' codec can't decode byte 0x81 in position 548: character maps to <undefined>
# Error processing article 269249: 'charmap' codec can't decode byte 0x81 in position 548: character maps to <undefined>
# Error processing article 269383: 'charmap' codec can't decode byte 0x81 in position 548: character maps to <undefined>
# Error processing article 269509: 'charmap' codec can't decode byte 0x81 in position 548: character maps to <undefined>
# Error processing article 269546: 'charmap' codec can't decode byte 0x81 in position 548: character maps to <undefined>
# Error processing article 269566: 'charmap' codec can't decode byte 0x81 in position 548: character maps to <undefined>
# Error processing article 269580: 'charmap' codec can't decode byte 0x81 in position 548: character maps to <undefined>
# Error processing article 269621: 'charmap' codec can't decode byte 0x81 in position 548: character maps to <undefined>
# Error processing article 270199: 'charmap' codec can't decode byte 0x81 in position 548: character maps to <undefined>
# Error processing article 271275: 'charmap' codec can't decode byte 0x81 in position 548: character maps to <undefined>
# Error processing article 271595: 'charmap' codec can't decode byte 0x81 in position 548: character maps to <undefined>
# Error processing article 272215: 'charmap' codec can't decode byte 0x81 in position 548: character maps to <undefined>
# Error processing article 272483: 'charmap' codec can't decode byte 0x81 in position 548: character maps to <undefined>
# Error processing article 272989: 'charmap' codec can't decode byte 0x81 in position 548: character maps to <undefined>
# Error processing article 273265: 'charmap' codec can't decode byte 0x81 in position 548: character maps to <undefined>
# Error processing article 274142: 'charmap' codec can't decode byte 0x81 in position 548: character maps to <undefined>
# Error processing article 274184: 'charmap' codec can't decode byte 0x81 in position 548: character maps to <undefined>
# Error processing article 274851: 'charmap' codec can't decode byte 0x81 in position 548: character maps to <undefined>
# Error processing article 276304: 'charmap' codec can't decode byte 0x81 in position 548: character maps to <undefined>
# Error processing article 276708: 'charmap' codec can't decode byte 0x81 in position 548: character maps to <undefined>
# Error processing article 276855: 'charmap' codec can't decode byte 0x81 in position 548: character maps to <undefined>
# Error processing article 277011: 'charmap' codec can't decode byte 0x81 in position 548: character maps to <undefined>
# Error processing article 277034: 'charmap' codec can't decode byte 0x81 in position 548: character maps to <undefined>
